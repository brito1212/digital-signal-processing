# %%
from scipy.fft import fft
from numpy import arange, floor, angle, pi
import matplotlib.pyplot as plt

def espectro1D(sinal, fs):
    fsinal = fft( sinal )
    
    N = sinal.size
    df = fs/N
    freq = arange(0,fs,df)
    
    # fig, axs = plt.subplots(2,1)
    # plt.figure(nfig)
    
    ax1 = plt.subplot(2,1,1)
    Ampl = 2*abs( fsinal[0:int(floor(N/2))] )/N
    print(Ampl[0])
    Ampl[0] = Ampl[0] / 2; # correcao na amplitude da componente DC
    print("COmponente DC: ", Ampl[0])
    ax1.stem( freq[0:int(floor(N/2))], Ampl )
    ax1.set_ylabel( 'Amplitude' )
    #axs[0].set_xlabel( 'Freq. [Hz]' )
    ax1.axis([0,fs/2,0,1.1*max(Ampl)])
    ax1.grid(True)

    ax2 = plt.subplot(2,1,2)
    Fase = (angle( fsinal[0:int(floor(N/2))] ) )*180/pi
    ax2.stem( freq[0:int(floor(N/2))], Fase )
    ax2.set_ylabel( 'Fase [graus]' )
    ax2.set_xlabel( 'Freq. [Hz]' )
    ax2.axis([0,fs/2,1.1*min(Fase),1.1*max(Fase)])
    ax2.grid(True)

    print("Fase: ", Fase)
    print("Amplitude: ", Ampl)
    print("Frequencia: ", freq)

    plt.show()

# %%
# Taxa de amostragem (assumida, deve ser conhecida ou especificada)
import numpy as np


fs = 24 # Exemplo de taxa de amostragem em Hz
signal = np.array([6.19642464, 0.42541302, -0.92906322, 3.8064145, -3.25193827, -2.12541302, -2.01542316, -2.1064145])
# Espectro do sinal principal contaminado
espectro1D(signal, fs)

print(sum(signal))
# Out:
# 2.500000040317474e-09
# COmponente DC:  1.250000020158737e-09
# Fase:  [-180.          -44.99999997   29.99999998  -22.50000002]
# Amplitude:  [1.25000002e-09 2.50000000e+00 1.70000000e+00 3.20000000e+00]
# Frequencia:  [ 0.  3.  6.  9. 12. 15. 18. 21.]
# -1.00000003833145e-08

# %%
import numpy as np


fs = 24 # Exemplo de taxa de amostragem em Hz
signal = np.array([6.19642464, 0.42541302, -0.92906322, 3.8064145, -3.25193827, -2.12541302, -2.01542316, -2.1064145])
# Espectro do sinal principal contaminado
espectro1D(signal, fs)

print(sum(signal))
